# %%
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sc

# %%
def f(x,a,b,c):
    return a*np.exp(-b*x) +c

# %%
with open('plots/rewards/fluctuations.pt', 'rb') as file:
        fluctuations = pickle.load(file)

# %%
description = 'without COIN_CHASER and modified Gamma'
with sns.axes_style('darkgrid'):
    x=np.arange(len(fluctuations))
    plt.plot(x,fluctuations)
    plt.xlabel('Training Round')
    plt.ylabel('| Q_TD - Q |')
    plt.tight_layout()
    plt.title(f'Convergence {description}')
    plt.savefig(f'plots/rewards/random_alpha=0001_gamma=0001/{description}')

# %%
#note down rewards with model working:
game_rewards = {
        e.COIN_COLLECTED: 12,
        e.KILLED_OPPONENT: 5,
        e.KILLED_SELF: -20,
        WAITING_EVENT: -3,
        e.INVALID_ACTION: -7,
        COIN_CHASER: 0.5,
        MOVED_AWAY_FROM_BOMB: 1,
        WAITED_IN_EXPLOSION_RANGE: -1,
        INVALID_ACTION_IN_EXPLOSION_RANGE: -2 
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9abda9a92303> in <module>
#       1 #note down rewards with model working:
#       2 game_rewards = {
# ----> 3         e.COIN_COLLECTED: 12,
#       4         e.KILLED_OPPONENT: 5,
#       5         e.KILLED_SELF: -20,
#
# NameError: name 'e' is not defined

# %%
field = np.array([[0,0,0,1],[1,1,1,0]])
rows, cols = np.where(field ==1)
print(rows)
print(cols)
# Out:
# [0 1 1 1]
# [3 0 1 2]

# %%
import numpy as np
from collections import deque

# %%
a = np.array([[1,2,3,4],[3,4,5,6]])
b = np.array([[0,1],[1,0],[1,0],[0,3]])
c = b.T
print(np.shape(a))
print(c)
a[b[0][0],b[0][1]]
# Out:
# (2, 4)
# [[0 1 1 0]
#  [1 0 0 3]]
# 2

# %%
a = [[1,2],3,[4,5]]
b=deque(a)

# %%
print(b)
# Out:
# deque([[1, 2], 3, [4, 5]])

# %%
if [1,2] in b: 
    print('yes')
# Out:
# yes

# %%
a = [1,2,0,4,5] 
print(a[2:])
# Out:
# [0, 4, 5]
